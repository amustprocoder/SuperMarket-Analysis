# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            background-color:blue;
#            font-size:250%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white
#           text-align:Center;">
#
#         Super Market🛒 Analysis
# </p>
# </div>

# %% [markdown]
# ![download.jpg](/workspaces/SuperMarket-Analysis/supermarket-2-retro-cartoon-banners-set-vector-98531558.jpg)

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:250%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     Workflow
#
# </p>
# </div>
#
#
# - Step 1: Importing the requred libraries
# - Step 2: Loading the data
# - Step 3: Basic understanding of the data
# - Step 4: Preprocessing
# - Step 5: Feature Engineering
#          - Feature Extraction
#          - Converting Dtypes
#          - Dropping irrelevant columns
#          - Feature selection
# - Step 6: Insights

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     Step 1: importing required libraries
#
# </p>
# </div>

# %%
import pandas as pd   # for data manipulation 
import numpy as np    # for numeric calculations 
import seaborn as sns  # for data visualizations 
import matplotlib.pyplot as plt  # for data visualizations

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     Step 2: loading dataset form Kaggle in csv format
#
# </p>
# </div>

# %%
df=pd.read_csv("/kaggle/input/supermarket-sales/supermarket_sales - Sheet1.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# ##### - Attributes Information

# - Invoice id: Computer generated sales slip invoice identification number

# - Branch: Branch of supercenter (3 branches are available identified by A, B and C).

# - City: Location of supercenters

# - Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.

# - Gender: Gender type of customer

# - Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# - Unit price: Price of each product in $

# - Quantity: Number of products purchased by customer

# - Tax: 5% tax fee for customer buying

# - Total: Total price including tax

# - Date: Date of purchase (Record available from January 2019 to March 2019)

# - Time: Purchase time (10am to 9pm)

# - Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)

# - COGS: Cost of goods sold

# - Gross margin percentage: Gross margin percentage
# - Gross income: Gross income

# - Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     Step 3: Basic understanding of the data
#
# </p>
# </div>
#
#
#
# - checking shape
# - info
# - data samples & data over view
# - checking missing values
# - dtypes
# - understanding of the columns

# %%
# checkinig shape of the data
df.shape

# """there are 1000 rowas and 17 columns in the data"""
# Out:
# (1000, 17)

# %% [markdown]
# ### preview of the data

# %%
 # random samples 
df.sample(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 993  690-01-6631      B   Mandalay        Normal    Male  Fashion accessories
# 646  778-89-7974      C  Naypyitaw        Normal    Male    Health and beauty
# 101  189-98-2939      C  Naypyitaw        Normal    Male  Fashion accessories
# 463  320-32-8842      C  Naypyitaw        Member  Female   Food and beverages
# 548  539-21-7227      B   Mandalay        Normal  Female    Sports and travel
# 461  234-03-4040      B   Mandalay        Member  Female   Food and beverages
# 373  382-25-8917      C  Naypyitaw        Normal    Male  Fashion accessories
# 792  744-16-7898      B   Mandalay        Normal  Female   Home and lifestyle
# 663  641-51-2661      C  Naypyitaw        Member  Female   Food and beverages
# 128  663-86-9076      C  Naypyitaw        Member  Female   Food and beverages
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %% [markdown]
# ## basic information of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
# Date & Time columns are in object type we will convert these into datetime dtype

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     Step 4: data preprocessing
#
# </p>
# </div>

# %%
#checking missing values 
df.isnull().sum() 

# there is no missing value in my data
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
import missingno as msn
msn.bar(df,color=(0.25, 0.25, 1))

# checking missing values with plot using missingno library
# Out:
# <Axes: >

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     detecting inconsistency in the data
#
# </p>
# </div>

# %%
# object type data
df_obj=df.select_dtypes(include='object')
for i in df_obj:
    print(i,'----',df[i].unique(),"#########",df[i].nunique())
# Out:
# Invoice ID ---- ['750-67-8428' '226-31-3081' '631-41-3108' '123-19-1176' '373-73-7910'
#  '699-14-3026' '355-53-5943' '315-22-5665' '665-32-9167' '692-92-5582'
#  '351-62-0822' '529-56-3974' '365-64-0515' '252-56-2699' '829-34-3910'
#  '299-46-1805' '656-95-9349' '765-26-6951' '329-62-1586' '319-50-3348'
#  '300-71-4605' '371-85-5789' '273-16-6619' '636-48-8204' '549-59-1358'
#  '227-03-5010' '649-29-6775' '189-17-4241' '145-94-9061' '848-62-7243'
#  '871-79-8483' '149-71-6266' '640-49-2076' '595-11-5460' '183-56-6882'
#  '232-16-2483' '129-29-8530' '272-65-1806' '333-73-7901' '777-82-7220'
#  '280-35-5823' '554-53-8700' '354-25-5821' '228-96-1411' '617-15-4209'
#  '132-32-9879' '370-41-7321' '727-46-3608' '669-54-1719' '574-22-5561'
#  '326-78-5178' '162-48-8011' '616-24-2851' '778-71-5554' '242-55-6721'
#  '399-46-5918' '106-35-6779' '635-40-6220' '817-48-8732' '120-06-4233'
#  '285-68-5083' '803-83-5989' '347-34-2234' '199-75-8169' '853-23-2453'
# ...

# %%
# numeric type data
df_num=df.select_dtypes(exclude='object')
for i in df_num:
    print(i,'----',df[i].unique(),"#########",df[i].nunique())
# Out:
# Unit price ---- [74.69 15.28 46.33 58.22 86.31 85.39 68.84 73.56 36.26 54.84 14.48 25.51
#  46.95 43.19 71.38 93.72 68.93 72.61 54.67 40.3  86.04 87.98 33.2  34.56
#  88.63 52.59 33.52 87.67 88.36 24.89 94.13 78.07 83.78 96.58 99.42 68.12
#  62.62 60.88 54.92 30.12 86.72 56.11 69.12 98.7  15.37 93.96 56.69 20.01
#  18.93 82.63 91.4  44.59 17.87 15.43 16.16 85.98 44.34 89.6  72.35 30.61
#  24.74 55.73 55.07 15.81 75.74 15.87 33.47 97.61 78.77 18.33 89.48 62.12
#  48.52 75.91 74.67 41.65 49.04 78.31 20.38 99.19 96.68 19.25 80.36 48.91
#  83.06 76.52 49.38 42.47 76.99 47.38 44.86 21.98 64.36 89.75 97.16 87.87
#  12.45 52.75 82.7  48.71 78.55 23.07 58.26 30.35 88.67 27.38 62.13 33.98
#  81.97 16.49 98.21 72.84 58.07 80.79 27.02 21.94 51.36 10.96 53.44 99.56
#  57.12 99.96 63.91 56.47 93.69 32.25 31.73 68.54 90.28 39.62 92.13 34.84
#  87.45 81.3  90.22 26.31 34.42 51.91 72.5  89.8  90.5  68.6  30.41 77.95
#  46.26 30.14 66.14 71.86 32.46 91.54 83.24 16.48 80.97 92.29 72.17 50.28
# ...

# %%
# All the columns have valid data or values

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     Step 5: feature engineering
#
# </p>
# </div>
#
# - feature Extract
# - feature selection

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# ## since the invoice id seems irrelevant so deleting this column

# %%
df.drop(columns=['Invoice ID'],inplace=True)

# """ Invoice ID has been dropped """

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Time']=pd.to_datetime(df['Time'])

# """ Date & Time columns have been converted into datetime dtypes """

# %%
 """checking dtypes after converting date & time columns into datatime dtype """
df.dtypes
# Out:
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     feature extraction
#
# </p>
# </div>

# %%
from datetime import datetime as dt

# %%
df['year']=df['Date'].dt.year
df['Days']=df['Date'].dt.day_name()
df['Month']=df['Date'].dt.month_name()
df['weekday']=df['Date'].dt.weekday
df['hour']=df['Time'].dt.hour

# %%
df.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date  ...      Payment    cogs  \
# 0         7  26.1415  548.9715 2019-01-05  ...      Ewallet  522.83
# 1         5   3.8200   80.2200 2019-03-08  ...         Cash   76.40
# 2         7  16.2155  340.5255 2019-03-03  ...  Credit card  324.31
# 3         8  23.2880  489.0480 2019-01-27  ...      Ewallet  465.76
# 4         7  30.2085  634.3785 2019-02-08  ...      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating  year      Days     Month  \
# ...

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     feature selection
#
# </p>
# </div>
#
#
# - correlation
# - data distribution
# - checking outliers

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     Checking Correlation
#
# </p>
# </div>

# %%
df.corr()
# Out:
# /tmp/ipykernel_20/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
# ...

# %%
#correlation with heatmap 
plt.figure(figsize=(10,5))
col={'color':'k','fontsize':10}
sns.heatmap(df.corr(),annot=True,cmap='cool',annot_kws=col,linewidth=1,linecolor='k')
# Out:
# /tmp/ipykernel_20/4192938191.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='cool',annot_kws=col,linewidth=1,linecolor='k')
# <Axes: >

# %% [markdown]
# # observations
# - 1. Tax, cogs, Total, gross income have prefect relations
# - 2. Tax column and gross income column give same information  & cogs column and Total column also give same information so will drop one column in each of them (with the company point of view we will Total column in cogs column and Total column )

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     distribution of the data
#
# </p>
# </div>

# %%
df.describe().T
# Out:
#                           count         mean         std          min  \
# Unit price               1000.0    55.672130   26.494628    10.080000
# Quantity                 1000.0     5.510000    2.923431     1.000000
# Tax 5%                   1000.0    15.379369   11.708825     0.508500
# Total                    1000.0   322.966749  245.885335    10.678500
# cogs                     1000.0   307.587380  234.176510    10.170000
# gross margin percentage  1000.0     4.761905    0.000000     4.761905
# gross income             1000.0    15.379369   11.708825     0.508500
# Rating                   1000.0     6.972700    1.718580     4.000000
# year                     1000.0  2019.000000    0.000000  2019.000000
# weekday                  1000.0     3.032000    1.973543     0.000000
# hour                     1000.0    14.910000    3.186857    10.000000
#
#                                  25%          50%          75%          max
# ...

# %% [markdown]
# # observation
# - Tax column and gross income might have outliers because 75 percentile is this 22.445250 and max is this 49.650000
# - Total column also has outliers 75 percentile is this 471.350250 and max is this 1042.650000
# - cogs column also has outliers 75 percentile is this 448.905000 and max is this 993.000000

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     detecting outlines with boxplot
#
# </p>
# </div>

# %%
pos=1
plt.figure(figsize=(15,10))
for i in ['Unit price', 'Quantity', 'Tax 5%', 'Total','cogs',
       'gross margin percentage', 'gross income', 'Rating']:
    plt.subplot(3,3,pos)
    plt.boxplot(df[i])
    pos=pos+1
    plt.title(i)

# %% [markdown]
# # observation
# Tax, gross income, Total and cogs columns have outliers

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     Dropping irrelevant columns
#
# </p>
# </div>

# %%
df.drop(columns=['gross income','cogs','gross margin percentage'],inplace=True)

# %%
# checking shape after dropping irrelevant columns
df.shape
# Out:
# (1000, 18)

# %%
print(df[df['Branch']=='A']['City'].unique())
print(df[df['Branch']=='B']['City'].unique())
print(df[df['Branch']=='C']['City'].unique())
# Out:
# ['Yangon']
# ['Mandalay']
# ['Naypyitaw']

# %% [markdown]
# #### Branch and City columns both are giving same information so that dropping thses columns

# %%
# dropping Branch column
df.drop(columns=['Branch'],inplace=True)

# %% [markdown]
# # data review after dropping irrelevant columns

# %%
df.head()
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2     Yangon        Normal    Male      Home and lifestyle       46.33
# 3     Yangon        Member    Male       Health and beauty       58.22
# 4     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date                Time      Payment  \
# 0         7  26.1415  548.9715 2019-01-05 2023-07-25 13:08:00      Ewallet
# 1         5   3.8200   80.2200 2019-03-08 2023-07-25 10:29:00         Cash
# 2         7  16.2155  340.5255 2019-03-03 2023-07-25 13:23:00  Credit card
# 3         8  23.2880  489.0480 2019-01-27 2023-07-25 20:33:00      Ewallet
# 4         7  30.2085  634.3785 2019-02-08 2023-07-25 10:37:00      Ewallet
#
#    Rating  year      Days     Month  weekday  hour
# ...

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:120%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Seems data has been cleaned, it ready for getting insights, so we move on insights.
#
# </p>
# </div>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:250%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     Insights
#
# </p>
# </div>

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity   Tax 5%     Total       Date                Time  Payment  \
# 0         7  26.1415  548.9715 2019-01-05 2023-07-25 13:08:00  Ewallet
# 1         5   3.8200   80.2200 2019-03-08 2023-07-25 10:29:00     Cash
#
#    Rating  year      Days    Month  weekday  hour
# 0     9.1  2019  Saturday  January        5    13
# 1     9.6  2019    Friday    March        4    10

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      find the total & average sales of the company
#
# </p>
# </div>

# %%
df['Total'].agg(['sum','mean'])
# Out:
# sum     322966.749000
# mean       322.966749
# Name: Total, dtype: float64

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#       find the total & avrage sale of each City
#
# </p>
# </div>

# %%
df.groupby(['City'])['Total'].agg(['sum','mean'])
# Out:
#                    sum        mean
# City
# Mandalay   106197.6720  319.872506
# Naypyitaw  110568.7065  337.099715
# Yangon     106200.3705  312.354031

# %%
plt.figure(figsize=(15,15),facecolor='yellow')
ax1=plt.subplot(2,2,1)
ax1.set_facecolor('tan')
sns.barplot(x='City',y='Total',data=df,palette='bright',errwidth=3,capsize=.1)
plt.title('average sale of the companyof each City',fontdict={'fontsize': 15,'fontweight': 'bold','color': 'black'})
ax2=plt.subplot(2,2,2)
ax2.set_facecolor('tan')
sns.barplot(x='City',y='Total',data=df,estimator='sum',palette='bright',capsize=.1,errwidth=3)
plt.title('Total sale of the company of each City',fontdict={'fontsize': 15,'fontweight': 'bold','color': 'black'});

# %% [raw]
# in each City the total sale is almost same but Naypyitaw City has heightset sales of company

# %% [markdown]
# # since naypyitaw is hot selling City so we would like to see the heightset sale on any day

# %%
c=df[df['City']=='Naypyitaw']
c[c['Total']==c['Total'].max()].T
# Out:
#                                350
# City                     Naypyitaw
# Customer type               Member
# Gender                      Female
# Product line   Fashion accessories
# Unit price                    99.3
# Quantity                        10
# Tax 5%                       49.65
# Total                      1042.65
# Date           2019-02-15 00:00:00
# Time           2023-07-25 14:53:00
# Payment                Credit card
# Rating                         6.6
# year                          2019
# Days                        Friday
# Month                     February
# weekday                          4
# hour                            14

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Find the hot salling month
# </p>
# </div>

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.barplot(x='Month',y='Total',data=df,estimator='sum',palette='bright',errwidth=2,capsize=.1,width=0.5)
plt.title('Hot selling month of the company',fontdict={'fontsize': 12,'fontweight': 'bold','color': 'black'});

# %%
# January is hot selling month of the company

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      find the hot saling month of each brach
#
# </p>
# </div>

# %%
df.groupby(['Month','City'])['Total'].agg(['sum'])
# Out:
#                            sum
# Month    City
# February Mandalay   34424.2710
#          Naypyitaw  32934.9825
#          Yangon     29860.1205
# January  Mandalay   37176.0585
#          Naypyitaw  40434.6810
#          Yangon     38681.1285
# March    Mandalay   34597.3425
#          Naypyitaw  37199.0430
#          Yangon     37659.1215

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.barplot(x='City',y='Total',data=df,hue='Month',palette='bright',capsize=.01,estimator=sum)
plt.title('Hot selling month of the company of each City',fontdict={'fontsize': 12,'fontweight': 'bold','color': 'black'})
plt.xticks(rotation=20)
;
# Out:
# ''

# %%
# From above output we can observe that January was found to be hot selling month of each City/Branch

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      find the average sale of the month
#
# </p>
# </div>

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.barplot(x='Month',y='Total',data=df,palette='bright',capsize=.01,width=.5)
plt.title('Average sale of the month',color='black',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Average sale of the month')

# %%
# January was the top average sales of the company

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      find the average  sale of the month of each brach
#
# </p>
# </div>

# %%
df.groupby(['City','Month'])['Total'].agg(['mean'])
# Out:
#                           mean
# City      Month
# Mandalay  February  315.819000
#           January   334.919446
#           March     308.904844
# Naypyitaw February  329.349825
#           January   331.431811
#           March     350.934368
# Yangon    February  317.660856
#           January   325.051500
#           March     296.528516

# %%
plt.figure(figsize=(10,6),facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.barplot(x='Month',y='Total',data=df,hue='City',palette='bright',capsize=.01,errwidth=3)
plt.title('average sale of the month of each City/Branch',color='black',fontsize=14,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'average sale of the month of each City/Branch')

# %%
# in January month Mandalay has average heightset sale
# in March month Naypyitaw has average heightset sale 
# in February also month Naypyitaw average heightset sale

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#       Sale trend of company over the three months
#
# </p>
# </div>

# %%
plt.figure(figsize=(15,5),facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.lineplot(x='Date',y='Total',data=df,color='green',markers='o',estimator=sum,palette='bright')
plt.title('sale trends of the company',color='black',fontsize=20,fontweight='bold')
plt.xlabel('Date',color='black',fontsize=15,fontweight='bold')
plt.ylabel('Total',color='black',fontsize=15,fontweight='bold')
# Out:
# /tmp/ipykernel_20/1421354931.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='Date',y='Total',data=df,color='green',markers='o',estimator=sum,palette='bright')
# Text(0, 0.5, 'Total')

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      find the sale trend of each City with respect to date
#
# </p>
# </div>

# %%
plt.figure(figsize=(15,10))
sns.relplot(x='Date',y='Total',data=df,kind='line',color='g',col='City')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Costumer visiting trend of each month at Yangon City
# </p>
# </div>

# %%
plt.figure(figsize=(15,3),facecolor='yellow')
a=df[df['City']=='Yangon']
a_jan=a[a['Month']=='January']
plt.subplot(1,3,1)
plt.hist(a_jan['Date'],edgecolor='red',bins=7)
plt.xticks(rotation=90)
plt.title('January',fontsize=15,fontweight='bold')
a_mar=a[a['Month']=='March']
plt.subplot(1,3,2)
plt.hist(a_jan['Date'],edgecolor='red',bins=7)
plt.xticks(rotation=90)
plt.title('February',fontsize=15,fontweight='bold')
a_jan=a[a['Month']=='January']
plt.subplot(1,3,3)
plt.hist(a_jan['Date'],edgecolor='red',bins=7)
plt.xticks(rotation=90)
plt.title('March',fontsize=15,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'March')

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Costumer visiting trend of each month at Mandalay City
# </p>
# </div>

# %%
plt.figure(figsize=(15,3),facecolor='yellow')
a=df[df['City']=='Mandalay']
a_jan=a[a['Month']=='January']
plt.subplot(1,3,1)
plt.hist(a_jan['Date'],edgecolor='red',bins=7,)
plt.xticks(rotation=90)
plt.title('January',fontsize=15,fontweight='bold')
a_mar=a[a['Month']=='March']
plt.subplot(1,3,2)
plt.hist(a_jan['Date'],edgecolor='red',bins=7)
plt.xticks(rotation=90)
plt.title('February',fontsize=15,fontweight='bold')
a_jan=a[a['Month']=='January']
plt.subplot(1,3,3)
plt.hist(a_jan['Date'],edgecolor='red',bins=7)
plt.xticks(rotation=90)
plt.title('March',fontsize=15,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'March')

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Costumer visiting trend of each month at Naypyitaw City
# </p>
# </div>

# %%
plt.figure(figsize=(15,3),facecolor='yellow')
a=df[df['City']=='Naypyitaw']
a_jan=a[a['Month']=='January']
plt.subplot(1,3,1)
plt.hist(a_jan['Date'],edgecolor='red',bins=7)
plt.xticks(rotation=90)
plt.title('January',fontsize=15,fontweight='bold')
a_mar=a[a['Month']=='March']
plt.subplot(1,3,2)
plt.hist(a_jan['Date'],edgecolor='red',bins=7)
plt.xticks(rotation=90)
plt.title('February',fontsize=15,fontweight='bold')
a_jan=a[a['Month']=='January']
plt.subplot(1,3,3)
plt.hist(a_jan['Date'],edgecolor='red',bins=7)
plt.xticks(rotation=90)
plt.title('March',fontsize=15,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'March')

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Hot selling day
# </p>
# </div>

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.barplot(x='Days',y='Total',data=df,estimator=sum,palette='bright',capsize=.01,errwidth=3)
plt.xticks(rotation=20)
plt.title('Hot selling day',fontsize=15,color='black',fontweight='bold');

# %%
# Saturday was the Hot selling day of the company

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#       Hot sellin day of each branch
# </p>
# </div>

# %%
df.groupby(['City','Days'])['Total'].agg([sum])
# Out:
#                             sum
# City      Days
# Mandalay  Friday     14417.7600
#           Monday     12734.7045
#           Saturday   21284.4240
#           Sunday     10415.3280
#           Thursday   15778.6230
#           Tuesday    18859.2390
#           Wednesday  12707.5935
# Naypyitaw Friday     14964.7155
#           Monday     10925.3130
#           Saturday   18070.9725
#           Sunday     17035.7460
#           Thursday   14148.3510
#           Tuesday    17667.7935
#           Wednesday  17755.8150
# Yangon    Friday     14543.8650
#           Monday     14239.0605
#           Saturday   16765.4130
#           Sunday     17006.8185
#           Thursday   15422.2740
#           Tuesday    14955.2130
#           Wednesday  13267.7265

# %%
plt.figure(figsize=(10,7),facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.barplot(x='City',y='Total',data=df,estimator=sum,hue='Days',capsize=.01,errwidth=3,palette='bright')
plt.title('Hot selling day of each branch',color='black',fontsize=15,fontweight='bold');

# %%
# In Yangon City Sunday was the Hot Selling Day 
# In Naypyitaw Saturday was the Hot Selling day
# In Mandalay City also Saturday was the Hot Selling day

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      find the total sale of weekday the weekend
# </p>
# </div>

# %%
### extract the weekdays & weekends column from Days column

# %%
df['weekday/weekend']=df['Days'].apply(lambda x: 'weekend' if x=='Saturday' or x=='Sunday' else 'weekday')

# %%
# After column extracttion preview of the data

# %%
df.sample(2)
# Out:
#           City Customer type  Gender        Product line  Unit price  \
# 923  Naypyitaw        Normal  Female   Sports and travel       83.14
# 463  Naypyitaw        Member  Female  Food and beverages       22.62
#
#      Quantity  Tax 5%    Total       Date                Time      Payment  \
# 923         7  29.099  611.079 2019-01-10 2023-07-25 10:31:00  Credit card
# 463         1   1.131   23.751 2019-03-17 2023-07-25 18:58:00         Cash
#
#      Rating  year      Days    Month  weekday  hour weekday/weekend
# 923     6.6  2019  Thursday  January        3    10         weekday
# 463     6.4  2019    Sunday    March        6    18         weekend

# %%
plt.figure(figsize=(5,5),facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.barplot(x='weekday/weekend',y='Total',data=df,estimator=sum,palette='bright',errwidth=3,capsize=.1,width=.6)
plt.title('Total weekdays & weekends sales',color='black',fontsize=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Total weekdays & weekends sales')

# %%
# Weekdays were heightset sales & Weekends were least sales

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      find the total sale of weekday the weekend of each City
#
# </p>
# </div>

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.barplot(x='City',y='Total',data=df,estimator=sum,hue='weekday/weekend',errwidth=3,capsize=.1,palette='bright')
plt.title('Total weekdays & weekends of each City',color='black',fontsize=12,fontweight='bold');

# %%
# weekdays were Hot selling days in each City/Branch

# %%
df.head()
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2     Yangon        Normal    Male      Home and lifestyle       46.33
# 3     Yangon        Member    Male       Health and beauty       58.22
# 4     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date                Time      Payment  \
# 0         7  26.1415  548.9715 2019-01-05 2023-07-25 13:08:00      Ewallet
# 1         5   3.8200   80.2200 2019-03-08 2023-07-25 10:29:00         Cash
# 2         7  16.2155  340.5255 2019-03-03 2023-07-25 13:23:00  Credit card
# 3         8  23.2880  489.0480 2019-01-27 2023-07-25 20:33:00      Ewallet
# 4         7  30.2085  634.3785 2019-02-08 2023-07-25 10:37:00      Ewallet
#
#    Rating  year      Days     Month  weekday  hour weekday/weekend
# ...

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Most populated product of the company
# </p>
# </div>

# %%
x=df['Product line'].value_counts()
x
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
plt.figure(facecolor='yellow')
colors = ["lime", "hotpink", "red", "m",'orange','cyan']
plt.pie(x.values,labels=x.index,autopct='%.2f%%',shadow=True,explode=[0.2,0,0,0,0,0],colors=colors,wedgeprops={'linewidth': 2.0, 'edgecolor': 'black'})
plt.title('most populated product',color='black',fontsize=15,fontweight='bold');

# %%
# Fashion accessories was the most populated product of the company

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Most populated product of the company of each City
# </p>
# </div>

# %%
df.groupby(['City'])['Product line'].value_counts()
# Out:
# City       Product line
# Mandalay   Fashion accessories       62
#            Sports and travel         62
#            Electronic accessories    55
#            Health and beauty         53
#            Food and beverages        50
#            Home and lifestyle        50
# Naypyitaw  Food and beverages        66
#            Fashion accessories       65
#            Electronic accessories    55
#            Health and beauty         52
#            Home and lifestyle        45
#            Sports and travel         45
# Yangon     Home and lifestyle        65
#            Electronic accessories    60
#            Sports and travel         59
#            Food and beverages        58
#            Fashion accessories       51
#            Health and beauty         47
# Name: Product line, dtype: int64

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.countplot(x='City',data=df,palette='bright',hue='Product line')
plt.title('most populated product of each City',color='black',fontsize=15,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'most populated product of each City')

# %%
# 1. -we can see almost very product was populated but Home and lifestyle were the most populated product in Yangon City
# 2. -Food and beverages was the most populated product in Naypyitaw City but also Fashion and accessories 
# 3. -And Mandalay City also almost every product was popular but Sports and travel & Fashion and accessories were most demanding products

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      most selling product
# </p>
# </div>

# %%
df.groupby(['Product line'])['Total'].agg(['sum'])
# Out:
#                                sum
# Product line
# Electronic accessories  54337.5315
# Fashion accessories     54305.8950
# Food and beverages      56144.8440
# Health and beauty       49193.7390
# Home and lifestyle      53861.9130
# Sports and travel       55122.8265

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.barplot(x='Product line',y='Total',data=df,estimator=sum,palette='bright',capsize=.1,errwidth=2)
plt.xticks(rotation=80);

# %%
# above output tells that each product was sold good but Food and beverages was the most selling product and Health and beauty was least selling product

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.lineplot(x='Product line',y='Total',data=df,estimator=sum,palette='bright',color='red')
plt.xticks(rotation=90)
plt.title('products selling trend',fontsize=12,fontweight='bold');
# Out:
# /tmp/ipykernel_20/3608636757.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='Product line',y='Total',data=df,estimator=sum,palette='bright',color='red')

# %%
# we can also trend

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:170%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Busy hour
# </p>
# </div>

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.countplot(x='hour',data=df,palette='bright')
plt.title('busy hour of the company',color='black',fontsize=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'busy hour of the company')

# %%
# 19 was the heightest selling hour

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Busy hour of each City
# </p>
# </div>

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.countplot(x='City',data=df,hue='hour',palette='bright')
plt.title('busy hour of the company of each City',color='black',fontsize=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'busy hour of the company of each City')

# %% [markdown]
#
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      most revenue generated time
# </p>
# </div>

# %%
plt.figure(figsize=(10,5),facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.lineplot(x='hour',y='Total',data=df,estimator=sum,palette='bright',color='red')
plt.title('most revenue generated time',fontsize=12,fontweight='bold')
# Out:
# /tmp/ipykernel_20/1116448097.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='hour',y='Total',data=df,estimator=sum,palette='bright',color='red')
# Text(0.5, 1.0, 'most revenue generated time')

# %%
plt.figure(facecolor='yellow',figsize=(10,5))
ax = plt.axes()
ax.set_facecolor("tan")
sns.lineplot(x='hour',y='Total',data=df,hue='Product line',estimator=sum,color='red',ci=None,palette='bright')
plt.title('peak hour of each product',fontsize=13,fontweight='bold')
# Out:
# /tmp/ipykernel_20/3604708703.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='hour',y='Total',data=df,hue='Product line',estimator=sum,color='red',ci=None,palette='bright')
# Text(0.5, 1.0, 'peak hour of each product')

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     Find the total number of customers
# </p>
# </div>

# %%
print('total customers: ',df['Gender'].count())
x=df['Gender'].value_counts()
x
# Out:
# total customers:  1000
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.countplot(x='Gender',data=df,width=.4,palette='bright')
plt.title('total male and female customers',color='black',fontsize=12,fontweight='bold');

# %%
# there are 499 meles and 501 are females

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.countplot(x='Gender',data=df,hue='City',width=.8,palette='bright')
plt.title('total male and female customers in each City',color='black',fontsize=12,fontweight='bold');

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:170%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Customers type comparison
# </p>
# </div>

# %%
df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
plt.figure(facecolor='yellow')
ax = plt.axes()
ax.set_facecolor("tan")
sns.countplot(x='Customer type',data=df,width=.6,palette='bright')
plt.title('count of customers type',color='black',fontsize=12,fontweight='bold');

# %%
# there are 499 normal type customers and 501 are Member type customers

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      which customer type generated the business
# </p>
# </div>

# %%
plt.figure(facecolor='yellow')
ax=plt.axes()
ax.set_facecolor('tan')
sns.barplot(x='Customer type',y='Total',data=df,estimator=sum,capsize=.03,errwidth=2,width=.5,palette='bright')
plt.title('sale comparison of customer type',fontsize=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'sale comparison of customer type')

# %%
# both customers type Member and Normal generated the business but Member type customers generated business most

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:left;">
#      Which customer type generated the business in each city/branch
# </p>
# </div>

# %%
plt.figure(facecolor='yellow')
ax=plt.axes()
ax.set_facecolor('tan')
sns.barplot(x='City',y='Total',data=df,hue='Customer type',estimator=sum,capsize=.03,errwidth=2,width=.6,palette='bright')
plt.title('sale comparison of customer type',fontsize=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'sale comparison of customer type')

# %%
# both customers type generated the business in each city but member type customers generated business most in each city

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:170%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      most trustworthy branch
# </p>
# </div>

# %%
df.groupby(['City'])['Gender'].agg(['count'])
# Out:
#            count
# City
# Mandalay     332
# Naypyitaw    328
# Yangon       340

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Which Payment mode customers used to pay
# </p>
# </div>

# %%
df['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
plt.figure(facecolor='yellow')
ax=plt.axes()
ax.set_facecolor('tan')
sns.countplot(x='Payment',data=df,palette='bright',width=.6)
plt.title('customer payment mode comparison',color='black',fontsize=15,fontweight='bold');

# %%
# 1. almost all payment mode customer likes but most likely used payment mode was Ewallet and least likely used payment mode was Credit card 💳 
# 2. what we can do to grow the business with the credit card customer as a business point of view we have to give the credit card discount offers to the customers, as customers will be increase the business/sale also will be increase

# %%
plt.figure(facecolor='yellow')
colors = ["lime", "hotpink", "m",'orange','cyan']
plt.pie(df['Payment'].value_counts().values,labels=df['Payment'].value_counts().index,autopct='%.2f%%',shadow=True,explode=[0.2,0,0],colors=colors,radius=1.2,startangle = 310,wedgeprops={'linewidth': 3.0, 'edgecolor': 'black'},textprops={'size': 'large'})
plt.title('customer payment mode comparison',color='black',fontsize=12,fontweight='bold');

# %%
# also see with the pie chart

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      Which Payment mode customers used to pay of each city
# </p>
# </div>

# %%
df.groupby(['City'])['Payment'].agg(['value_counts'])
# Out:
#                        value_counts
# City      Payment
# Mandalay  Ewallet               113
#           Cash                  110
#           Credit card           109
# Naypyitaw Cash                  124
#           Ewallet               106
#           Credit card            98
# Yangon    Ewallet               126
#           Cash                  110
#           Credit card           104

# %%
plt.figure(facecolor='yellow')
ax=plt.axes()
ax.set_facecolor('tan')
sns.barplot(x='City',y='Total',data=df,hue='Payment',estimator=sum,palette='bright')
plt.title('Payment mode comparison of each city',color='black',fontsize=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Payment mode comparison of each city')

# %%
# 1. in Yangon city customers used to pay with Ewallet 
# 2. in Naypyitaw city customers used to pay with Cash
# 3. mostly each payment mode equally used to pay by the customers but credit card 💳 mode was the most likely mode of the customers 
# except Mandalay city in other city credit card 💳 mode was the least likely mode to grow the business we can give the offeres or discounts on credit card mode, so that the credit card payment type customers will visiting

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      find the average, min and max of the rating
# </p>
# </div>

# %%
df['Rating'].agg(['max','mean','min'])
# Out:
# max     10.0000
# mean     6.9727
# min      4.0000
# Name: Rating, dtype: float64

# %%
print(len(df[df['Rating']==df['Rating'].max()]),f"customers had given {df['Rating'].max()} rating that is maximum rating")
print('maximum Rating percentage given by the customers  ',len(df[df['Rating']==df['Rating'].max()])*100/df.shape[0],'\n')

print(len(df[df['Rating']==df['Rating'].min()]),f"customers had given {df['Rating'].min()} rating that is minimum rating")
print('minimum Rating percentage given by the customers  ',len(df[df['Rating']==df['Rating'].min()])*100/df.shape[0],'\n')

print(df[(df['Rating']>5) & (df['Rating']<8)]['Rating'].unique(),'-these are Average Ratings given by the customers')
print(len(df[(df['Rating']>5) & (df['Rating']<8)]['Rating']),'customers had given rating that is Average rating')
print('Average Rating percentage given by the customers --',len(df[(df['Rating']>5) & (df['Rating']<8)]['Rating'])*100/df.shape[0])
# Out:
# 5 customers had given 10.0 rating that is maximum rating
# maximum Rating percentage given by the customers   0.5
#
# 11 customers had given 4.0 rating that is minimum rating
# minimum Rating percentage given by the customers   1.1
#
# [7.4 5.3 5.8 7.2 5.9 6.8 7.1 5.7 6.9 5.1 6.  6.7 7.7 7.5 7.  7.6 7.9 6.3
#  5.6 6.5 6.1 6.6 5.4 6.4 5.5 7.3 7.8 5.2 6.2] -these are Average Ratings given by the customers
# 497 customers had given rating that is Average rating
# Average Rating percentage given by the customers -- 49.7

# %%
plt.figure(facecolor='yellow')
ax=plt.axes()
ax.set_facecolor('tan')
plt.hist(df['Rating'],edgecolor='red')
plt.title('distribution of the Rating',color='black',fontsize=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'distribution of the Rating')

# %%
# max Rating 10 had given only 5 customers that is not good number and min ranting 4.0 had given only 11 customers which is good 
# but if we see min rating is close to average ratings and average ratings had given 497 of 1000 customers it's indicates that customers are satisfied

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#     find the rating distribution of each City
# </p>
# </div>

# %%
plt.figure(figsize=(15,5),facecolor='yellow')
a=df[df['City']=='Mandalay']
ax=plt.subplot(1,3,1)
ax.set_facecolor('tan')
plt.hist(a['Rating'],edgecolor='red',bins=7)
plt.title('Customer Rating in Mandalay City',color='black',fontsize=13,fontweight='bold')
b=df[df['City']=='Naypyitaw']
ax1=plt.subplot(1,3,2)
ax1.set_facecolor('tan')
plt.hist(b['Rating'],edgecolor='red',bins=7)
plt.title('Customer Rating in Naypyitaw City',color='black',fontsize=13,fontweight='bold')
c=df[df['City']=='Yangon']
ax2=plt.subplot(1,3,3)
ax2.set_facecolor('tan')
plt.hist(c['Rating'],edgecolor='red',bins=7)
plt.title('Customer Rating in Yangon City',color='black',fontsize=13,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Customer Rating in Yangon City')

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      find the most selling product in each City
# </p>
# </div>

# %%
df.groupby(['City','Product line'])['Total'].agg(['sum'])
# Out:
#                                          sum
# City      Product line
# Mandalay  Electronic accessories  17051.4435
#           Fashion accessories     16413.3165
#           Food and beverages      15214.8885
#           Health and beauty       19980.6600
#           Home and lifestyle      17549.1645
#           Sports and travel       19988.1990
# Naypyitaw Electronic accessories  18968.9745
#           Fashion accessories     21560.0700
#           Food and beverages      23766.8550
#           Health and beauty       16615.3260
#           Home and lifestyle      13895.5530
#           Sports and travel       15761.9280
# Yangon    Electronic accessories  18317.1135
#           Fashion accessories     16332.5085
#           Food and beverages      17163.1005
#           Health and beauty       12597.7530
#           Home and lifestyle      22417.1955
#           Sports and travel       19372.6995

# %%
plt.figure(figsize=(10,10),facecolor='yellow')
ax=plt.axes()
ax.set_facecolor('tan')
sns.barplot(x='City',y='Total',data=df,estimator='sum',hue='Product line',palette='bright')
plt.xticks(rotation=20)
plt.title('Hot selling product in each City',color='black',fontsize=15,fontweight='bold') ;

# %%
# 1. Home and lifestyle was the hot selling product of Yangon City
# 2. Food and beverages was the hot selling product of Naypyitaw City
# 3. Health and beauty & Spots and travel were hot selling products in Mandalay City
# for other products we have to do advertisement and asking to the customers about the product how product is and we have to understand customers require to grow the business we have work on these points

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      most likely product by the member type customer
# </p>
# </div>

# %%
df['Customer type'].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %%
x=df[df['Customer type']=='Member']
x['Product line'].value_counts()
# Out:
# Food and beverages        94
# Sports and travel         87
# Fashion accessories       86
# Home and lifestyle        83
# Electronic accessories    78
# Health and beauty         73
# Name: Product line, dtype: int64

# %%
plt.figure(facecolor='yellow')
ax=plt.axes()
ax.set_facecolor('tan')
sns.countplot(x='Product line',data=x,palette='bright')
plt.title('most likely product by the member type customer',color='black',fontsize=12,fontweight='bold')
plt.xticks(rotation=80);

# %%
# Food and beverages was the most likely product of member type customers

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      most likely product by the normal type customers
# </p>
# </div>

# %%
y=df[df['Customer type']=='Normal']
y['Product line'].value_counts()
# Out:
# Electronic accessories    92
# Fashion accessories       92
# Food and beverages        80
# Sports and travel         79
# Health and beauty         79
# Home and lifestyle        77
# Name: Product line, dtype: int64

# %%
plt.figure(facecolor='yellow')
ax=plt.axes()
ax.set_facecolor('tan')
sns.countplot(x='Product line',data=y,palette='bright')
plt.title('most likely product by the normal type customer',color='black',fontsize=12,fontweight='bold')
plt.xticks(rotation=80);

# %%
# Electronic accessories and Fashion accessories were the most likely product of normal type customers

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:10px;
#            background-color:magenta;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#  <p style="padding:10px;
#            color:black;
#           text-align:Center;">
#      find the demanding product by the male and female customer
# </p>
# </div>

# %%
plt.figure(figsize=(8,3),facecolor='yellow')
ax=plt.axes()
ax.set_facecolor('tan')
sns.countplot(x='Product line',data=df,hue='Gender',palette='bright')
plt.xticks(rotation=80)
plt.title('likely product by the male and females customers',color='black',fontsize=12,fontweight='bold') ;
